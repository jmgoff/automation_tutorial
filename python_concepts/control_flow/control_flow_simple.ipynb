# %% [markdown]
# controlling flow in python

# %% [markdown]
#  for loops<br>
#  for <iterable>:<br>
#      do <something>

# %%
a = [1,2,3]
for i in a:
# to do things in a for loop, the corresponding line must be indented
    print(i)

# %% [markdown]
#  logicals

# %%
b = [2,4,5]

# %%
if b[0] == (2*a[0]):
    print(b[0],a[0])

# %% [markdown]
#  while loops<br>
#  while <condition><br>
#      do <something>
