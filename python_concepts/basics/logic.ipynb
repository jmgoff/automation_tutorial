# %% [markdown]
# Logic

# %%
a = 1
b = 1
c = 2

# %% [markdown]
# values equal?

# %%
print(a == b)

# %% [markdown]
# are values not equal?

# %%
print(a != b)

# %% [markdown]
# is x less than y?

# %%
print(a < b, a < c)

# %% [markdown]
# is x greater than y?

# %%
print(b > a,c > a)

# %% [markdown]
# is x less than or equal to y

# %%
print(a <= b)

# %% [markdown]
# is x greater than or equal to y

# %%
print(a >= b)
