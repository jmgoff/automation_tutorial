# %% [markdown]
# modules may be imported using import commands:

# %%
import numpy as np
# numpy libraries contain objects and data types that are convenient for math

# %% [markdown]
# for example, consider this numpy array

# %%
a = np.array([1,2,3])

# %%
print(a)
print(type(a)

# %% [markdown]
# math is easy with numpy

# %%
print(a*4)

# %% [markdown]
# ... less so with other formats sometimes<br>
#  (will return error)

# %%
c = [1,2,3]
print (c*4)

# %% [markdown]
# Note, you may load a module without giving it an abbreviated reference

# %%
import numpy
b = numpy.array([1,2,3])
print(b)
print(type(b))
